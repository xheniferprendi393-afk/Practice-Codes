# %%
# differnt types of data
x = 100
y = "john"
z = 10.5
w = True

# %%
# ways of stroing data structure
f = ["apple","orange","mango"]
d = {"apple":100, "orange":200,"orange":200}

# %%
# if else condtion
age = 19
if age <2:
    print("you are a baby")
elif age <12:
    print("you are a kid")
elif age < 20:
    print("you are ta teen ager")
else:
    print("soemthing")
# Out:
# you are ta teen ager

# %%
## loops
for i in range(10):
    print("maria")
# Out:
# maria
# maria
# maria
# maria
# maria
# maria
# maria
# maria
# maria
# maria

# %%
fruit = ["apple","orange","mango","strawberry"]
for each in fruit:
    print(each,"is a fruit")
# Out:
# apple is a fruit
# orange is a fruit
# mango is a fruit
# strawberry is a fruit

# %%
friends = ["red","pink","orange"]
for each in friends:
    print("Hello!!",each,"is invited to the dinner")
# Out:
# Hello!! red is invited to the dinner
# Hello!! pink is invited to the dinner
# Hello!! orange is invited to the dinner

# %%
def add(x,y):
    z = x+y
    return z

# %%
add(10,23)
# Out:
# 33

# %%
x = 10
print("the value is " + str(x) )
# Out:
# the value is 10

# %%
str(x)
# Out:
# '10'

# %%
def a(n):
    print("you gave value "+ str(n) )

# %%
a
# Out:
# <function __main__.a(n)>

# %%
a(10)
# Out:
# you gave value 10

# %%
a(20)
# Out:
# you gave value 20

# %%
# if else condtion
age = 8
if age <2:
    print("you are a baby")
elif age <12:
    print("you are a kid")
elif age < 20:
    print("you are ta teen ager")
else:
    print("soemthing")
# Out:
# you are a kid

# %%
# if else condtion
age = 6
if age <2:
    print("you are a baby")
elif age <12:
    print("you are a kid")
elif age < 20:
    print("you are ta teen ager")
else:
    print("soemthing")
# Out:
# you are a kid

# %%
def age_checker(age):
    if age <2:
        print("you are a baby")
    elif age <12:
        print("you are a kid")
    elif age < 20:
        print("you are ta teen ager")
    else:
        print("soemthing")

# %%
age_checker(9)
# Out:
# you are a kid

# %%
age_checker(18)
# Out:
# you are ta teen ager

# %%
age_checker(2)
# Out:
# you are a kid

# %%
# please make a function called hello that take parater x
# and print half of x

# %%
def hello(x):
 print(x/2)

# %%
hello(9)
# Out:
# 4.5

# %%
hello(28)
# Out:
# 14.0

# %%
def login(name):
    if name == "admin":
        print("welcome admin")
    else:
        print("sorry "+name + " you are now allowed to login")

# %%
login("admin")
# Out:
# welcome admin

# %%
login("ali")
# Out:
# sorry ali you are now allowed to login

# %%
## please make a function that take a name and print hello with name

# %%
def greeting(name):
    print("Hello " +name)

# %%
greeting("Jane")
# Out:
# Hello Jane

# %%
greeting("123")
# Out:
# Hello 123
